# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import probplot

# %%
df = pd.read_csv("data/mlb_stats.csv")

# %%
df.head()
# Out:
#   last_name, first_name  player_id  year  player_age   pa  home_run  \
# 0       Cabrera, Miguel     408234  2023          40  370         4
# 1        Peralta, David     444482  2023          35  422         7
# 2     Blackmon, Charlie     453568  2023          36  413         8
# 3     Maldonado, Martín     455117  2023          36  407        15
# 4       Solano, Donovan     456781  2023          35  450         5
#
#    k_percent  bb_percent  batting_avg  on_base_plus_slg  ...  avg_swing_speed  \
# 0       20.0         8.4        0.257             0.675  ...             68.3
# 1       17.1         4.7        0.259             0.675  ...             72.1
# 2       13.3         9.4        0.279             0.803  ...             66.9
# 3       34.2         7.4        0.191             0.606  ...             71.8
# 4       22.2         8.9        0.282             0.760  ...             68.2
#
#    fast_swing_rate  launch_angle_avg  sweet_spot_percent  barrel_batted_rate  \
# 0              0.7               7.4                34.2                 4.2
# 1             24.5               8.2                31.1                 4.9
# 2              1.6              18.1                39.0                 4.9
# 3             15.6              18.1                32.8                 8.5
# 4              6.3              13.1                43.1                 6.1
#
#    hard_hit_percent  avg_best_speed  whiff_percent  pull_percent  \
# 0              37.6       98.972071           25.6          35.7
# 1              44.2      100.838135           22.5          38.4
# 2              31.5       97.605452           19.6          45.5
# 3              40.0       99.511384           34.3          46.0
# 4              43.7      100.102936           25.4          34.2
#
#    groundballs_percent
# 0                 49.8
# 1                 49.1
# 2                 36.4
# 3                 38.7
# 4                 41.0
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (961, 22)

# %% [markdown]
# # Abstract

# %% [markdown]
# # Introduction

# %% [markdown]
# # Methodology

# %% [markdown]
# # Data

# %% [markdown]
# ### Data Source

# %% [markdown]
# The data was sourced from [Baseball Savant](https://baseballsavant.mlb.com/), the official advanced statistics webpage for Major League Baseball. We used their Custom Leaderboard feature to make a custom dataset linked [here](https://baseballsavant.mlb.com/leaderboard/custom?year=2025%2C2024%2C2023&type=batter&filter=&min=250&selections=player_age%2Cpa%2Chome_run%2Ck_percent%2Cbb_percent%2Cbatting_avg%2Con_base_plus_slg%2Cb_gnd_into_dp%2Cwoba%2Cavg_swing_speed%2Cfast_swing_rate%2Claunch_angle_avg%2Csweet_spot_percent%2Cbarrel_batted_rate%2Chard_hit_percent%2Cavg_best_speed%2Cwhiff_percent%2Cpull_percent%2Cgroundballs_percent&chart=false&x=pa&y=pa&r=no&chartType=beeswarm&sort=pa&sortDir=desc). As a group we chose to include 22 total variables (columns). Each observation is a player's batting statistics within a season. We included observations from three different years (the 2023, 2024, and 2025 seasons).

# %% [markdown]
# #### Observations and Sample

# %% [markdown]
# There are 961 total observations (rows) in the dataset. Out of the total Baseball Savant database, we do not have a completely random sample of the data. However, in order to draw proper conclusions from each observation, we have to put nonrandom filters on the observations to control for as much random noise as possible. The main filters are the seasons we are using (2023-2025), and only players with a minimum of 250 plate appearances in a season are considered. We still include every possible data point matching the criteria we filter for. In totality, we have every MLB player's single season batting statistics from 2023 to 2025 who had at least 250 plate appearances. Since we are not leaving out any observations after filtering the data, we have a census of the population space described above. Our scope of inference is the entire population space since we are not leaving out any observations. For MLB players who have at least 250 plate appearances in a season, it's reasonable to assume that our findings can apply to hitter statistics in the present and near future.

# %% [markdown]
# ### Missingness and Duplicates

# %% [markdown]
# Below, we check for missingness in the dataset by using the `missingno` library to construct a missingness bar plot. We can see that there is no `NaN` values which is a good sign. However we don't know for sure if there are secretly missing values until we perform exploratory data analysis and analyze the distributions of the variables. This makes sense since each observation is a player with plenty of plate appearances which makes each stat trackable.

# %%
msno.bar(df, figsize = (15, 3))
# Out:
# <Axes: >

# %% [markdown]
# Additionally, we will check for duplicate values in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are no duplicate values in the dataset!

# %% [markdown]
# ### Restructuring and Relabeling

# %% [markdown]
# Now let's check the names of the columns to see if we need to change them. Ideally we only want lowercase letters and underscores that act as spaces.

# %%
df.columns
# Out:
# Index(['last_name, first_name', 'player_id', 'year', 'player_age', 'pa',
#        'home_run', 'k_percent', 'bb_percent', 'batting_avg',
#        'on_base_plus_slg', 'b_gnd_into_dp', 'woba', 'avg_swing_speed',
#        'fast_swing_rate', 'launch_angle_avg', 'sweet_spot_percent',
#        'barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed',
#        'whiff_percent', 'pull_percent', 'groundballs_percent'],
#       dtype='str')

# %% [markdown]
# Most of the column names appear to be tidied up which is great! The only column names that we should change are `last_name, first_name` and `on_base_plus_slg`. `last_name, first_name` contains a space and comma which we do not want. We will rename the column to `player_name`. `on_base_plus_slg` is an okay column name, but as the outcome variable it will be called constantly and the name is a tad long. Since we already know this variable under a different and much shorter name (OPS), we will convert the column name to `ops`.

# %%
df = df.rename(columns = {"last_name, first_name": "player_name",
                          "on_base_plus_slg": "ops"})
df.columns
# Out:
# Index(['player_name', 'player_id', 'year', 'player_age', 'pa', 'home_run',
#        'k_percent', 'bb_percent', 'batting_avg', 'ops', 'b_gnd_into_dp',
#        'woba', 'avg_swing_speed', 'fast_swing_rate', 'launch_angle_avg',
#        'sweet_spot_percent', 'barrel_batted_rate', 'hard_hit_percent',
#        'avg_best_speed', 'whiff_percent', 'pull_percent',
#        'groundballs_percent'],
#       dtype='str')

# %% [markdown]
# Next we will take a look at the data type of each column to verify that each variable is the correct data type.

# %% [markdown]
# ### Type Correction / Reformatting

# %%
df.dtypes
# Out:
# player_name                str
# player_id                int64
# year                     int64
# player_age               int64
# pa                       int64
# home_run                 int64
# k_percent              float64
# bb_percent             float64
# batting_avg            float64
# ops                    float64
# b_gnd_into_dp            int64
# woba                   float64
# avg_swing_speed        float64
# fast_swing_rate        float64
# launch_angle_avg       float64
# sweet_spot_percent     float64
# barrel_batted_rate     float64
# hard_hit_percent       float64
# avg_best_speed         float64
# whiff_percent          float64
# pull_percent           float64
# groundballs_percent    float64
# dtype: object

# %% [markdown]
# It turns out that all the non-identifier variables we selected are in fact numeric data types, and we don't need to change any of them. Technically `player_id` as an integer does not hold any numeric value but it is an identifier and can be mostly left out of our analysis and any of our models.

# %% [markdown]
# As for reformatting, we could standardize the `player_name` values, but for the purposes of this project it is unnecessary since `player_id` already accurately differentiates players, and `player_name` will not be a part of our models.

# %% [markdown]
# ### Exploratory Data Analysis and Visualizations

# %% [markdown]
# We will now start performing EDA to be more informed about our variables and their relationships to each other and the outcome variable `ops`. First I want to isolate a list of variables that we are interested in exploring. We will just remove the identifier variables `player_name` and `player_id`.

# %%
df_eda = df.drop(columns = ["player_name", "player_id"])
eda_vars = df_eda.columns.tolist()
eda_vars
# Out:
# ['year',
#  'player_age',
#  'pa',
#  'home_run',
#  'k_percent',
#  'bb_percent',
#  'batting_avg',
#  'ops',
#  'b_gnd_into_dp',
#  'woba',
#  'avg_swing_speed',
#  'fast_swing_rate',
#  'launch_angle_avg',
#  'sweet_spot_percent',
#  'barrel_batted_rate',
#  'hard_hit_percent',
#  'avg_best_speed',
#  'whiff_percent',
#  'pull_percent',
#  'groundballs_percent']

# %% [markdown]
# We are now ready to perform univariate analysis. Note that this dataset does not have any categorical variables, so we will mostly be working with histograms and scatter plots instead of bar plots.

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
# Next, we will create a massive multiplot of histograms of each variable we are exploring. We can use `seaborn` and `matplotlib` for this multiplot.

# %%
fig, axes = plt.subplots(5, 4, figsize = (15, 16))

axes = axes.flatten()

for i, col in enumerate(eda_vars):
    sns.histplot(
        data = df,
        x = col,
        bins = 30,
        ax = axes[i],
        color = "steelblue"
    )
    axes[i].set_title(col, fontsize = 9)
    axes[i].set_xlabel("")
    axes[i].set_ylabel("Count", fontsize = 9)

plt.suptitle("Histograms of Covariates", fontsize = 13, fontweight = "bold", y = 1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# Here I will make a few comments on the variables.
#
# `year`: This variable is mostly uniform. I'm not too interested in using this variable as a predictor, more just looking to make sure there is a relatively even amount of samples from year to year.
#
# `player_age`: This variable is slightly right skewed.
#
# `pa`: Plate appearances appears to be mostly uniform besides the upper bound values.
#
# `home_run`: The amount of home runs hit is heavily right skewed, as it is very hard to accumulate a lot of home runs.
#
# `k_percent`, `batting_avg`, `launch_angle_avg`, `sweet_spot_percent`, `hard_hit_percent`, `avg_best_speed`, `whiff_percent`, `pull_percent`, `groundballs_percent`: appear to be roughly normal.
#
# `bb_percent`, `barrel_batted_rate`: Appear to be decently right skewed.
#
# `avg_swing_speed` appears to be symmetric but with a sharp peak.
#
# `fast_swing_rate` appears to follow a logistic curve with lower values being way more frequent.

# %% [markdown]
# Additionally, we will create a summary table with some summary statistics as well as skew and kurtosis.

# %%
# Summary Table
summary_table = df[eda_vars].describe()[1:].T
summary_table['skew'] = df[eda_vars].skew()
summary_table['kurtosis'] = df[eda_vars].kurt()
summary_table = summary_table.round(2)

summary_table
# Out:
#                         mean     std      min      25%      50%      75%  \
# year                 2023.98    0.81  2023.00  2023.00  2024.00  2025.00
# player_age             28.04    3.64    20.00    25.00    28.00    31.00
# pa                    473.53  134.64   250.00   352.00   463.00   588.00
# home_run               15.52    9.52     0.00     9.00    14.00    21.00
# k_percent              22.11    6.00     3.10    17.90    22.10    26.10
# bb_percent              8.39    2.88     2.30     6.30     8.10    10.30
# batting_avg             0.25    0.03     0.16     0.23     0.25     0.27
# ops                     0.73    0.09     0.47     0.67     0.73     0.79
# b_gnd_into_dp           8.50    4.73     0.00     5.00     8.00    11.00
# woba                    0.32    0.04     0.21     0.29     0.32     0.34
# avg_swing_speed        71.61    2.70    62.60    69.95    71.70    73.40
# fast_swing_rate        23.25   18.87     0.00     7.90    18.70    34.40
# launch_angle_avg       13.41    4.51    -0.70    10.50    13.50    16.40
# sweet_spot_percent     34.19    3.67    22.00    31.80    34.20    36.70
# barrel_batted_rate      8.54    4.25     0.00     5.50     8.10    11.20
# hard_hit_percent       40.30    7.70    16.70    35.80    40.60    45.90
# avg_best_speed        100.06    2.44    93.59    98.50   100.00   101.67
# whiff_percent          24.95    6.12     5.30    20.60    24.90    29.30
# pull_percent           39.20    5.99    23.10    35.30    39.00    43.40
# groundballs_percent    42.29    6.50    20.90    37.70    42.40    46.60
#
#                          max  skew  kurtosis
# year                 2025.00  0.04     -1.49
# player_age             40.00  0.38     -0.34
# pa                    753.00  0.12     -1.16
# home_run               60.00  1.11      1.88
# k_percent              42.80  0.12     -0.02
# bb_percent             19.20  0.57      0.35
# batting_avg             0.35  0.04      0.33
# ops                     1.16  0.51      1.04
# b_gnd_into_dp          31.00  0.81      0.99
# woba                    0.48  0.39      0.73
# avg_swing_speed        81.20 -0.14      0.42
# fast_swing_rate        98.60  1.00      0.53
# launch_angle_avg       28.90 -0.08     -0.01
# sweet_spot_percent     47.80  0.04      0.18
# barrel_batted_rate     27.60  0.60      0.62
# hard_hit_percent       64.20 -0.26      0.04
# avg_best_speed        108.19  0.10      0.05
# whiff_percent          44.30 -0.07     -0.19
# pull_percent           58.10  0.06     -0.17
# groundballs_percent    61.80  0.16     -0.06

# %% [markdown]
# `home_run` has the highest absolute kurtosis at 1.88 which makes sense since its outliers values are on the higher end. It is also the most skewed.

# %% [markdown]
# #### Bivariate Analysis

# %% [markdown]
# We will start by making scatter plots of each variable against `ops`.

# %%
eda_vars
# Out:
# ['year',
#  'player_age',
#  'pa',
#  'home_run',
#  'k_percent',
#  'bb_percent',
#  'batting_avg',
#  'ops',
#  'b_gnd_into_dp',
#  'woba',
#  'avg_swing_speed',
#  'fast_swing_rate',
#  'launch_angle_avg',
#  'sweet_spot_percent',
#  'barrel_batted_rate',
#  'hard_hit_percent',
#  'avg_best_speed',
#  'whiff_percent',
#  'pull_percent',
#  'groundballs_percent']

# %%
bivariate_vars = eda_vars.copy()
bivariate_vars.remove("ops")

fig, axes = plt.subplots(5, 4, figsize = (15, 16))
axes = axes.flatten()

for i, col in enumerate(bivariate_vars):
    sns.scatterplot(
        data = df,
        x = col,
        y = "ops",
        ax = axes[i],
        color = "steelblue",
        alpha = 0.5
    )

    axes[i].set_title(f"{col} vs OPS")
    axes[i].set_ylabel("OPS")

for j in range(len(bivariate_vars), len(axes)):
    axes[j].set_visible(False)

plt.suptitle("Scatterplots of Covariates Against OPS")
plt.tight_layout()
plt.show()

# %% [markdown]
# Off the bat we see a very strong relationship between OPS and woba (weighted on-base average). This can be attributed to the fact that both wOBA and OPS are both some direct function of On Base Percentage. While they have their differences, it may not be suitable to include wOBA into our models since they are both partly derived from On Base Percentage.
#
# For the other plots, there is a lot of noise in each, but some of the stats appear to have a mild linear relationship with OPS. We can further verify this with a correlation matrix

# %%
corr_matrix = df[eda_vars].corr()

# Reverse order of rows to match the columns
corr_matrix = corr_matrix.iloc[::-1]


plt.figure(figsize = (15, 15))

sns.heatmap(corr_matrix,
            annot = True,
            cmap = "coolwarm",
            fmt = ".2f",
            center = 0)

plt.show()

# %% [markdown]
# As shown in the correlation heatmap, `ops` has a very high correlation with `woba`. It is also decently correlated with `home_run`, `bb_percent`, `batting_avg`, `fast_swing_rate`, `barrel_batted_rate`, `hard_hit_percentage`, and `avg_best_speed`. A lot of the covariates are correlated with each other which is expected since some of them record the same or similar metrics.

# %% [markdown]
# Lastly, I want to see if there is an overall trend in OPS through time in years. We only have three years to choose from but small changes in between years are still significant. We will create a time series plot.

# %%
plt.figure(figsize = (8, 5))

ops_by_year = df.groupby("year")["ops"].mean().reset_index()

sns.lineplot(
    data = ops_by_year,
    x = "year",
    y = "ops",
    marker = "o"
)

plt.xticks([2023, 2024, 2025])

plt.show()

# %% [markdown]
# Based on this three year sample there doesn't appear to be a discernable trend in OPS. This is expected though because our data doesn't have a wide enough timespan.

# %% [markdown]
# # Results

# %% [markdown]
# ### Implementation of Chose Methodology

# %% [markdown]
# For this model, we will try to predict a player's season-long hitting performance through using a Originary Least Squares Multiple Linear Regression equation. The model will attempt to estimate the value of Y (ops) given a structural vector of independent features X, consisting of `home_run`, `bb_percent`, `batting_avg`, `fast_swing_rate`, `barrel_batted_rate`, `hard_hit_percentage`, and `avg_best_speed`

# %%
model = smf.ols(formula='ops ~ home_run + bb_percent + batting_avg + '
                        'fast_swing_rate + barrel_batted_rate + '
                        'hard_hit_percent + avg_best_speed', data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ops   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                     2060.
# Date:                Thu, 04 Jun 2026   Prob (F-statistic):               0.00
# Time:                        21:27:24   Log-Likelihood:                 2265.9
# No. Observations:                 959   AIC:                            -4516.
# Df Residuals:                     951   BIC:                            -4477.
# Df Model:                           7
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.3266      0.135      2.423      0.016       0.062       0.591
# home_run               0.0026      0.000     21.685      0.000       0.002       0.003
# bb_percent             0.0077      0.000     27.477      0.000       0.007       0.008
# batting_avg            2.1008      0.028     74.174      0.000       2.045       2.156
# fast_swing_rate     8.197e-05   7.82e-05      1.049      0.295   -7.14e-05       0.000
# barrel_batted_rate     0.0077      0.000     20.232      0.000       0.007       0.008
# hard_hit_percent      -0.0005      0.000     -1.223      0.222      -0.001       0.000
# avg_best_speed        -0.0027      0.002     -1.816      0.070      -0.006       0.000
# ==============================================================================
# Omnibus:                       66.070   Durbin-Watson:                   1.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.690
# Skew:                           0.625   Prob(JB):                     1.83e-18
# Kurtosis:                       3.693   Cond. No.                     2.05e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.05e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# The large condition model strongly suggest multicollinearity, as `barrel_batted_rate` fundamentally results in high barrel rate and high exit velocity. This results in studies of the `hard_hit_percent` and `avg_best_speed` to provide no new information. `batting_avg`is also a massive contributer to `ops` which is mathematically correct as it is apart of the calculation of On-Base Percentage which is part of ops (which stands for On-Base Percentage + Slugging). We also are double counting when comparing `homeruns` and `barrel_batted_rate` sinc they are similar in the sense that most homeruns are the result from a barrel off the bat.

# %% [markdown]
# ### Using Lasso to solve multicollinearity

# %%
print(df[['home_run', 'bb_percent', 'batting_avg', 'fast_swing_rate', 
          'barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed']].isna().sum())
# Out:
# home_run              0
# bb_percent            0
# batting_avg           0
# fast_swing_rate       2
# barrel_batted_rate    0
# hard_hit_percent      0
# avg_best_speed        0
# dtype: int64

# %%
feature_cols = [
    'home_run', 'bb_percent', 'batting_avg', 
    'fast_swing_rate', 'barrel_batted_rate', 
    'hard_hit_percent', 'avg_best_speed'
]

df_clean = df.dropna(subset=feature_cols + ['ops'])

X = df_clean[feature_cols]
y = df_clean['ops']

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

lasso_cv = LassoCV(alphas=np.logspace(-4, 1, 100), cv=5, random_state=42)
lasso_cv.fit(X_scaled, y)

print(f"Optimal Alpha Penalty: {lasso_cv.alpha_:.6f}")
# Out:
# Optimal Alpha Penalty: 0.000100

# %%
lasso_coefs = pd.DataFrame({
    'Feature': feature_cols,
    'Standardized Coefficient': lasso_cv.coef_
})
lasso_coefs['Abs_Impact'] = lasso_coefs['Standardized Coefficient'].abs()
lasso_coefs = lasso_coefs.sort_values(by='Abs_Impact', ascending=False).drop(columns=['Abs_Impact'])

print("\n--- LASSO Coefficient Results ---")
print(lasso_coefs.to_string(index=False))

y_pred = lasso_cv.predict(X_scaled)
r2 = r2_score(y, y_pred)
print(f"\nLASSO Model R-squared: {r2:.4f}")
# Out:
# --- LASSO Coefficient Results ---
#            Feature  Standardized Coefficient
#        batting_avg                  0.059572
# barrel_batted_rate                  0.032155
#           home_run                  0.025168
#         bb_percent                  0.022032
#     avg_best_speed                 -0.005012
#   hard_hit_percent                 -0.003973
#    fast_swing_rate                  0.000883
#
# LASSO Model R-squared: 0.9381

# %% [markdown]
# To address the multicollinearity in the OLS linear regression model, we ran a LASSO Linear Regression model weakens/shrinks coefficients that are redudant variables. All features were standardized to mean of 0 and variance of 1 using a StandardScalar which allows us to compare the impact of larger values such as fast_swing_rate with avg_best_speed. `barrel_batted_rate` has the power category compared to `hard_hit_percent` with `fast_swing_rate` also becaing strunk to virtuallly zero, indicating that swinging fast doesn't

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV
from sklearn.metrics import r2_score

feature_cols = [
    'home_run', 'bb_percent', 'batting_avg', 
    'fast_swing_rate', 'barrel_batted_rate', 
    'hard_hit_percent', 'avg_best_speed'
]

X = df[feature_cols].copy()
y = df['ops']

X = X.fillna(X.median())

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

ridge_cv = RidgeCV(alphas=np.logspace(-3, 3, 100), cv=5)
ridge_cv.fit(X_scaled, y)

ridge_results = pd.DataFrame({
    'Feature': feature_cols,
    'Ridge Standardized Coef': ridge_cv.coef_
})
ridge_results['Abs_Impact'] = ridge_results['Ridge Standardized Coef'].abs()
ridge_results = ridge_results.sort_values(by='Abs_Impact', ascending=False).drop(columns=['Abs_Impact'])

y_pred_ridge = ridge_cv.predict(X_scaled)
r2_ridge = r2_score(y, y_pred_ridge)

print(f"Optimal Ridge Alpha: {ridge_cv.alpha_:.6f}")
print(f"Ridge Model R-squared: {r2_ridge:.4f}")
print("\n--- Ridge Coefficient Results ---")
print(ridge_results.to_string(index=False))
# Out:
# Optimal Ridge Alpha: 0.932603
# Ridge Model R-squared: 0.9375
#
# --- Ridge Coefficient Results ---
#            Feature  Ridge Standardized Coef
#        batting_avg                 0.059680
# barrel_batted_rate                 0.032566
#           home_run                 0.025048
#         bb_percent                 0.022244
#     avg_best_speed                -0.006464
#   hard_hit_percent                -0.003551
#    fast_swing_rate                 0.001553

# %% [markdown]
# # Conclusion

# %% [markdown]
# # References
